# %%
# confirm the environment
import sys, platform, os
print("Python:", sys.version)
print("Executable:", sys.executable)
print("Platform:", platform.platform())
print("Working dir:", os.getcwd())
# Out:
# Python: 3.10.19 | packaged by conda-forge | (main, Oct 22 2025, 22:29:10) [GCC 14.3.0]
# Executable: /mnt/vol1/protein_cancer/envs/python_ai_env/bin/python
# Platform: Linux-5.4.0-216-generic-x86_64-with-glibc2.31
# Working dir: /mnt/vol1/Multi-Omics-Cancer-Subtype-Discovery

# %%
#list project files
from pathlib import Path
PROJECT=Path.cwd()
print("project folder:", PROJECT)

print("\nTop-level files/folders:")
for p in sorted(PROJECT.iterdir()):
    print(" -", p.name)
# Out:
# project folder: /mnt/vol1/Multi-Omics-Cancer-Subtype-Discovery
#
# Top-level files/folders:
#  - .Rhistory
#  - .Rproj.user
#  - .git
#  - .gitignore
#  - .ipynb_checkpoints
#  - .virtual_documents
#  - Multi-Omics-Cancer-Subtype-Discovery.Rproj
#  - README.md
#  - Untitled2.ipynb

# %%
#  Creating the project structure

from pathlib import Path

PROJECT= Path.cwd()
DATA= PROJECT / "data"
RAW= DATA / "raw"
PROCESSED= DATA / "processed"

#Create the folders

RAW.mkdir(parents=True, exist_ok=True)
PROCESSED.mkdir(parents=True, exist_ok=True)

print("\nContents of the data/:")
for p in sorted(DATA.iterdir()):
    print(" -", p.name)

print("\nContents of data/raw/:")
for p in sorted(RAW.iterdir()):
    print(" -", p.name)

print("\nContent of the data/processed/:")
for p in sorted(PROCESSED.iterdir()):
    print(" -", p.name)
# Out:
# Contents of the data/:
#  - processed
#  - raw
#
# Contents of data/raw/:
#
# Content of the data/processed/:
