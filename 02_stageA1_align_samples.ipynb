# %%
from pathlib import Path
import pandas as pd

PROJECT = Path.cwd()
RAW = PROJECT / "data" / "raw"

print("Project:", PROJECT)
print("RAW folder:", RAW)
print("RAW files:", [p.name for p in sorted(RAW.glob("*.csv"))])
# Out:
# Project: /mnt/vol1/Multi-Omics-Cancer-Subtype-Discovery
# RAW folder: /mnt/vol1/Multi-Omics-Cancer-Subtype-Discovery/data/raw
# RAW files: ['clinical.csv', 'proteomics.csv', 'transcriptomics.csv']

# %%
# %%capture

import pandas as pd

clinical_path = RAW / "clinical.csv"
prot_path = RAW / "proteomics.csv"
rna_path = RAW / "transcriptomics.csv"

clinical = pd.read_csv(clinical_path, index_col=0)
proteomics = pd.read_csv(prot_path, index_col=0)
transcriptomics = pd.read_csv(rna_path, index_col=0)

# %%
print("clinical:", clinical.shape)
print("proteomics:", proteomics.shape)
print("transcriptomics:", transcriptomics.shape)

clinical.head(3)
# Out:
# clinical: (103, 124)
# proteomics: (115, 11949)
# transcriptomics: (121, 59286)
#            tumor_code discovery_study type_of_analyzed_samples  \
# Patient_ID
# C3L-00006        UCEC             Yes         Tumor_and_Normal
# C3L-00008        UCEC             Yes                    Tumor
# C3L-00032        UCEC             Yes                    Tumor
#
#             confirmatory_study  type_of_analyzed_samples.1 age     sex   race  \
# Patient_ID
# C3L-00006                  NaN                         NaN  64  Female  White
# C3L-00008                  NaN                         NaN  58  Female  White
# C3L-00032                  NaN                         NaN  50  Female  White
#
#                          ethnicity ethnicity_race_ancestry_identified  ...  \
# Patient_ID                                                             ...
# C3L-00006   Not Hispanic or Latino                              White  ...
# C3L-00008   Not Hispanic or Latino                              White  ...
# C3L-00032   Not Hispanic or Latino                              White  ...
#
#            additional_treatment_pharmaceutical_therapy_for_new_tumor  \
# Patient_ID
# C3L-00006                                                 NaN
# C3L-00008                                                 NaN
# C3L-00032                                                 NaN
#
#            additional_treatment_immuno_for_new_tumor  \
# Patient_ID
# C3L-00006                                        NaN
# C3L-00008                                        NaN
# C3L-00032                                        NaN
#
#            number_of_days_from_date_of_initial_pathologic_diagnosis_to_date_of_additional_surgery_for_new_tumor_event_loco-regional  \
# Patient_ID
# C3L-00006                                                 NaN
# C3L-00008                                                 NaN
# C3L-00032                                                 NaN
#
#            number_of_days_from_date_of_initial_pathologic_diagnosis_to_date_of_additional_surgery_for_new_tumor_event_metastasis  \
# Patient_ID
# C3L-00006                                                 NaN
# C3L-00008                                                 NaN
# C3L-00032                                                 NaN
#
#            Recurrence-free survival, days  \
# Patient_ID
# C3L-00006                             NaN
# C3L-00008                             NaN
# C3L-00032                             NaN
#
#            Recurrence-free survival from collection, days  \
# Patient_ID
# C3L-00006                                             NaN
# C3L-00008                                             NaN
# C3L-00032                                             NaN
#
#            Recurrence status (1, yes; 0, no) Overall survival, days  \
# Patient_ID
# C3L-00006                                  0                  737.0
# C3L-00008                                  0                  898.0
# C3L-00032                                  0                 1710.0
#
#            Overall survival from collection, days  \
# Patient_ID
# C3L-00006                                   737.0
# C3L-00008                                   898.0
# C3L-00032                                  1710.0
#
#            Survival status (1, dead; 0, alive)
# Patient_ID
# C3L-00006                                  0.0
# C3L-00008                                  0.0
# C3L-00032                                  0.0
#
# [3 rows x 124 columns]

# %%
# Convert index values to strings (avoids subtle mismatches)
clin_ids = clinical.index.astype(str)
prot_ids = proteomics.index.astype(str)
rna_ids  = transcriptomics.index.astype(str)

common = sorted(set(clin_ids) & set(prot_ids) & set(rna_ids))

print("Sample counts:")
print(" clinical:", len(clin_ids))
print(" proteomics:", len(prot_ids))
print(" transcriptomics:", len(rna_ids))
print(" common:", len(common))


# Subset and force the same order
clinical_a = clinical.loc[common].copy()
proteomics_a = proteomics.loc[common].copy()
transcriptomics_a = transcriptomics.loc[common].copy()

print("\nAligned shapes:")
print(" clinical_a:", clinical_a.shape)
print(" proteomics_a:", proteomics_a.shape)
print(" transcriptomics_a:", transcriptomics_a.shape)
# Out:
# Sample counts:
#  clinical: 103
#  proteomics: 115
#  transcriptomics: 121
#  common: 95
#
# Aligned shapes:
#  clinical_a: (95, 124)
#  proteomics_a: (95, 11949)
#  transcriptomics_a: (95, 59286)
